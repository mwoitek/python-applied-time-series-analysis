# %% [markdown]
# # Random Walk

# %%
import warnings

import matplotlib.pyplot as plt
import numpy as np
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.tsa.stattools import acf

warnings.filterwarnings("ignore")

# %%
plt.rcParams["figure.figsize"] = [10, 7.5]

# %% [markdown]
# ## Simulation of Random Walk

# %%
steps = np.random.standard_normal(1000)
steps[0] = 0

random_walk = np.cumsum(steps)

# %%
random_walk[:10]
# Out:
# array([ 0.        , -1.38157398, -2.15934171, -1.4375085 ,  0.07841748,
#        -1.75441189, -3.66772055, -1.85739635, -2.25180026, -2.19926532])

# %%
plt.plot(random_walk)
plt.title("Simulated Random Walk")
# Out:
# Text(0.5, 1.0, 'Simulated Random Walk')

# %%
random_walk_acf_coef = acf(random_walk)
random_walk_acf_coef
# Out:
# array([1.        , 0.9880608 , 0.9759667 , 0.96354856, 0.95042514,
#        0.93689966, 0.92323569, 0.90935746, 0.89501844, 0.87996598,
#        0.86667669, 0.85416512, 0.84318788, 0.83207847, 0.8208666 ,
#        0.80921904, 0.79774341, 0.78631968, 0.77474441, 0.76318562,
#        0.75102593, 0.73827799, 0.72467213, 0.71133486, 0.69822333,
#        0.68436868, 0.67166569, 0.65995915, 0.64789178, 0.63694531,
#        0.62750954])

# %%
plot_acf(random_walk, lags=20, auto_ylims=True);  # fmt: skip

# %%
random_walk_diff = np.diff(random_walk, n=1)

# %%
plt.plot(random_walk_diff)
plt.title("Noise")
# Out:
# Text(0.5, 1.0, 'Noise')

# %%
plot_acf(random_walk_diff, lags=20, auto_ylims=True);  # fmt: skip
